# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('lab_4.csv')
data
# Out:
#     Time (seconds)  light  temperature
# 0             2.48    121           25
# 1             2.99    185           25
# 2             3.49    206           24
# 3             3.99    198           24
# 4             4.50    149           24
# 5             5.00    168           24
# 6             5.51    191           24
# 7             6.01    190           24
# 8             6.51    158           24
# 9             7.02    170           24
# 10            7.52    185           24
# 11            8.03    200           24
# 12            8.53      0           24
# 13            9.03    179           24
# 14            9.54    202           24
# 15           10.04    199           24
# 16           10.55    150           24
# 17           11.05    176           24
# 18           11.55    196           24

# %%
plt.plot(data['Time (seconds)'], data['light'], label='Light')
plt.plot(data['Time (seconds)'], data['temperature'], label='Temperature')
plt.title('Lighta And Temperature Over Time')
plt.legend()
