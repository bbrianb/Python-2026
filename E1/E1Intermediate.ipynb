# %% [markdown]
# E1 Intermediate
#
# Brian Bannon
#
# I have created 3 functions to calculate information about the savings from installing solar panels. I created another function to display the data in a formatted table. I copied 2 functions from E1 Novice because they are still useful.

# %%
# Old functions

def calculate_panel_energy(panel_wattage: float, hours_sunlight: float) -> float:
    return panel_wattage * hours_sunlight / 1000

def calculate_installation_cost(num_panels: int, cost_per_panel: float, installation_cost_per_panel: float, fixed_cost: float) -> float:
    return num_panels * (cost_per_panel + installation_cost_per_panel) + fixed_cost

# %%
def calculate_max_panels(available_area: float, panel_area: float, max_budget: float, cost_per_panel: float, installation_cost_per_panel: float, fixed_cost: float) -> tuple[int, str]:
    """
    Function to determine the binding constraint and max number of panels
    :param available_area: the area available
    :param panel_area: the area of one panel
    :param max_budget: the budget
    :param cost_per_panel: the cost of one panel
    :param installation_cost_per_panel: the cost of one installing one panel
    :param fixed_cost: the fixed cost
    :return: the max number of panels and the binding constraint
    """
    max_panels_space = int(available_area / panel_area)
    budget = max_budget - fixed_cost
    max_panels_budget = int(budget / (cost_per_panel + installation_cost_per_panel))
    if max_panels_space < max_panels_budget:
        return max_panels_space, 'Space'
    else:
        return max_panels_budget, 'Budget'

# %%
def calculate_payback_period(total_cost: float, annual_energy_kwh: float, electricity_rate: float, annual_rate_increase: float) -> int:
    """
    Function to calculate how long it takes to pay back the cost of installing solar panels
    :param total_cost: the cost of installing panels
    :param annual_energy_kwh: how much energy the panels generate in a year in kWh
    :param electricity_rate: how much electricity is worth
    :param annual_rate_increase: how much the electricity rate increases year over year
    :return: the number of years it takes to cover the installation cost
    """
    cumulative_savings = 0
    current_rate = electricity_rate
    years = 0
    while cumulative_savings < total_cost and years < 50:
        annual_savings = annual_energy_kwh * current_rate
        cumulative_savings += annual_savings
        current_rate *= 1 + annual_rate_increase
        years += 1
    return years

# %%
def calculate_lifetime_savings(total_cost: float, annual_energy_kwh: float, electricity_rate: float, annual_rate_increase: float, system_lifetime: int) -> tuple[float, float, float]:
    """
    Function to calculate how much money is saved throughout the system lifetime by using solar panels
    :param total_cost: the total cost of installing the solar panels
    :param annual_energy_kwh: the amount of energy produced in a year
    :param electricity_rate: how much the electricity is worth
    :param annual_rate_increase: how much the electricity rate increases year over year
    :param system_lifetime: the number of years the system will be in use
    :return: how much money is saved during the whole lifetime
    """
    total_savings = 0
    current_rate = electricity_rate
    for year in range(system_lifetime):
        total_savings += annual_energy_kwh * current_rate
        current_rate *= 1 + annual_rate_increase
    net_savings = total_savings - total_cost
    roi_percent = net_savings / total_cost * 100
    return total_savings, net_savings, roi_percent

# %%
def print_data(data_dict: dict) -> None:
    spacing = 26
    max_panels, limiting = calculate_max_panels(data_dict['area'], data_dict['panel area'], data_dict['budget'], data_dict['panel cost'], data_dict['panel installation'], data_dict['fixed'])
    panel_production = calculate_panel_energy(data_dict['wattage'], data_dict['hours'])
    annual_energy_kwh = max_panels * panel_production * 365
    total_cost = calculate_installation_cost(max_panels, data_dict['panel cost'], data_dict['panel installation'], data_dict['fixed'])
    payback = calculate_payback_period(total_cost, annual_energy_kwh, data_dict['rate'], data_dict['increase'])
    total_savings, net_savings, roi_percent = calculate_lifetime_savings(total_cost, annual_energy_kwh, data_dict['rate'], data_dict['increase'], data_dict['lifetime'])
    print(f'{data_dict['name']}\n'
          f'{'Available roof area':<{spacing}} {data_dict['area']} sq ft\n'
          f'{'Panel area':<{spacing}} {data_dict['panel area']} sq ft\n'
          f'{'Panel wattage':<{spacing}} {data_dict['wattage']} W\n'
          f'{'Peak sun hours':<{spacing}} {data_dict['hours']} hours\n'
          f'{'Maximum budget':<{spacing}} ${data_dict['budget']:,.2f}\n'
          f'{'Cost per panel':<{spacing}} ${data_dict['panel cost']:,.2f}\n'
          f'{'Installation per panel':<{spacing}} ${data_dict['panel installation']:,.2f}\n'
          f'{'Fixed costs':<{spacing}} ${data_dict['fixed']:,.2f}\n'
          f'{'Current electricity rate':<{spacing}} ${data_dict['rate']:,.4f}/kWh\n'
          f'{'Annual rate increase':<{spacing}} {data_dict['increase']*100:.0f}%\n'
          f'{'System lifetime':<{spacing}} {data_dict['lifetime']} years\n'
          f'{'Maximum panels':<{spacing}} {max_panels}\n'
          f'{'Limiting factor':<{spacing}} {limiting}\n'
          f'{'Annual energy production':<{spacing}} {annual_energy_kwh:,.1f} kWh\n'
          f'{'Total installation cost':<{spacing}} ${total_cost:,.2f}\n'
          f'{'Payback period':<{spacing}} {payback} years\n'
          f'{'Total savings':<{spacing}} ${total_savings:,.2f}\n'
          f'{'Net savings':<{spacing}} ${net_savings:,.2f}\n'
          f'{'ROI':<{spacing}} {roi_percent:.1f}%'
          )

# %%
data = {
    'name': 'Budget-Conscious Homeowner',
    'area': 600,
    'panel area': 18,
    'wattage': 350,
    'hours': 4.5,
    'budget': 12_000,
    'panel cost': 275,
    'panel installation': 150,
    'fixed': 3_000,
    'rate': 0.14,
    'increase': 0.03,
    'lifetime': 25
}
print_data(data)
# Out:
# Budget-Conscious Homeowner
# Available roof area        600 sq ft
# Panel area                 18 sq ft
# Panel wattage              350 W
# Peak sun hours             4.5 hours
# Maximum budget             $12,000.00
# Cost per panel             $275.00
# Installation per panel     $150.00
# Fixed costs                $3,000.00
# Current electricity rate   $0.1400/kWh
# Annual rate increase       3%
# System lifetime            25 years
# Maximum panels             21
# Limiting factor            Budget
# Annual energy production   12,072.4 kWh
# Total installation cost    $11,925.00
# Payback period             7 years
# Total savings              $61,620.99
# Net savings                $49,695.99
# ROI                        416.7%

# %%
data = {
    'name': 'Space-Limited Urban Home',
    'area': 400,
    'panel area': 17.5,
    'wattage': 400,
    'hours': 5.5,
    'budget': 25_000,
    'panel cost': 350,
    'panel installation': 175,
    'fixed': 4_000,
    'rate': 0.18,
    'increase': 0.04,
    'lifetime': 25
}
print_data(data)
# Out:
# Space-Limited Urban Home
# Available roof area        400 sq ft
# Panel area                 17.5 sq ft
# Panel wattage              400 W
# Peak sun hours             5.5 hours
# Maximum budget             $25,000.00
# Cost per panel             $350.00
# Installation per panel     $175.00
# Fixed costs                $4,000.00
# Current electricity rate   $0.1800/kWh
# Annual rate increase       4%
# System lifetime            25 years
# Maximum panels             22
# Limiting factor            Space
# Annual energy production   17,666.0 kWh
# Total installation cost    $15,550.00
# Payback period             5 years
# Total savings              $132,428.99
# Net savings                $116,878.99
# ROI                        751.6%

# %%
data = {
    'name': 'Large Suburban Home',
    'area': 1000,
    'panel area': 19,
    'wattage': 370,
    'hours': 4.0,
    'budget': 30_000,
    'panel cost': 300,
    'panel installation': 140,
    'fixed': 3_500,
    'rate': 0.11,
    'increase': 0.025,
    'lifetime': 25
}
print_data(data)
# Out:
# Large Suburban Home
# Available roof area        1000 sq ft
# Panel area                 19 sq ft
# Panel wattage              370 W
# Peak sun hours             4.0 hours
# Maximum budget             $30,000.00
# Cost per panel             $300.00
# Installation per panel     $140.00
# Fixed costs                $3,500.00
# Current electricity rate   $0.1100/kWh
# Annual rate increase       2%
# System lifetime            25 years
# Maximum panels             52
# Limiting factor            Space
# Annual energy production   28,090.4 kWh
# Total installation cost    $26,380.00
# Payback period             8 years
# Total savings              $105,545.58
# Net savings                $79,165.58
# ROI                        300.1%

# %%
data = {
    'name': 'Scenario 1 with 5% rate increase',
    'area': 600,
    'panel area': 18,
    'wattage': 350,
    'hours': 4.5,
    'budget': 12_000,
    'panel cost': 275,
    'panel installation': 150,
    'fixed': 3_000,
    'rate': 0.14,
    'increase': 0.05,
    'lifetime': 25
}
print_data(data)
# Out:
# Scenario 1 with 5% rate increase
# Available roof area        600 sq ft
# Panel area                 18 sq ft
# Panel wattage              350 W
# Peak sun hours             4.5 hours
# Maximum budget             $12,000.00
# Cost per panel             $275.00
# Installation per panel     $150.00
# Fixed costs                $3,000.00
# Current electricity rate   $0.1400/kWh
# Annual rate increase       5%
# System lifetime            25 years
# Maximum panels             21
# Limiting factor            Budget
# Annual energy production   12,072.4 kWh
# Total installation cost    $11,925.00
# Payback period             7 years
# Total savings              $80,665.12
# Net savings                $68,740.12
# ROI                        576.4%

# %%
data = {
    'name': 'Scenario 2 with lower panel costs',
    'area': 400,
    'panel area': 17.5,
    'wattage': 400,
    'hours': 5.5,
    'budget': 25_000,
    'panel cost': 350*0.9**2,
    'panel installation': 175,
    'fixed': 4_000,
    'rate': 0.1947,
    'increase': 0.04,
    'lifetime': 25-2
}
print_data(data)
# Out:
# Scenario 2 with lower panel costs
# Available roof area        400 sq ft
# Panel area                 17.5 sq ft
# Panel wattage              400 W
# Peak sun hours             5.5 hours
# Maximum budget             $25,000.00
# Cost per panel             $283.50
# Installation per panel     $175.00
# Fixed costs                $4,000.00
# Current electricity rate   $0.1947/kWh
# Annual rate increase       4%
# System lifetime            23 years
# Maximum panels             22
# Limiting factor            Space
# Annual energy production   17,666.0 kWh
# Total installation cost    $14,087.00
# Payback period             4 years
# Total savings              $125,949.80
# Net savings                $111,862.80
# ROI                        794.1%

# %% [markdown]
# QUESTION 1
# In the first scenario, although 600 square feet of space allows for a lot of panels, the limiting factor is budget because a budget of only 12000 dollars with 3000 dollars of fixed costs and 425 dollars per panel allows for only 21 panels.
#
# In the second scenario, 400 square feet of space is not enough for a lot of panels even though the budget is high enough for more panels.
#
# In the third scenario, although there is a ton of space, the budget is also very high and is enough to fill the entire area with panels.
#
# QUESTION 2
# The second option has the shortest payback period because the total installation cost is not that high and the value of energy is $0.18, which is higher than the first scenario, and the panels produce a lot of energy per year.
#
# QUESTION 3
# Scenario 2 has the highest ROI, scenario 1 has the second most and scenario 3 has the least ROI.
#
# QUESTION 4
# If the rate increase in the first scenario were 5 instead of 3, the payback period would still be 7 years. This implies that a rate increase <= 5% does not have much of an effect on the payback period.
#
# QUESTION 5
# The total savings if the cost of panels drops 10% is about $5,000 higher for scenario 2.
